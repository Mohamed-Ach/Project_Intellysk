# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("GINF_DATA.csv",encoding='latin1')
df.head(5)
# Out:
#    Numero appoge     Last Name First Name sex  age        City  Annee Filier  \
# 0       20000773       ABETIOU    SOFIANE   M   20     Larache   2023   GINF
# 1       19001211      ACHERNAN    MOHAMED   M   20      Tanger   2023   GINF
# 2       19001137         AFOUD       HIND   F   20      Tanger   2023   GINF
# 3       20000734  AIT OUKHADOU      SELMA   F   20  Casablanca   2023   GINF
# 4       20000761       AKIIRNE       AMAL   F   20  Casablanca   2023   GINF
#
#   Matiere famsize  ... romantic  famrel  freetime Dciga Wciga health absences  \
# 0     C++     LE3  ...       no       5         4     1     2      5       10
# 1     C++     LE3  ...       no       4         3     1     2      5        2
# 2     C++     GT3  ...       no       5         4     1     2      3        2
# 3     C++     GT3  ...       no       4         4     1     1      1        0
# 4     C++     GT3  ...       no       4         3     1     1      5        2
#
#    CC1  CC2  Note_Final
# ...

# %%
plt.figure(figsize=(6,5))
ax = sns.countplot(data =df,x="sex")
ax.bar_label(ax.containers[0])
plt.title("Gender Distribution")
plt.show()

# %%
sns.barplot(x='internet', y='Note_Final', data=df)
plt.xlabel('Accès à Internet')
plt.ylabel('Moyenne des notes')
plt.title('Impact de l\'accès à Internet sur les notes')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x='internet', y='Note_Final', data=df, ci=None, palette='viridis')

plt.xlabel('Accès à Internet')
plt.ylabel('Moyenne des notes')
plt.title('Impact de l\'accès à Internet sur les notes')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3320\426492381.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='internet', y='Note_Final', data=df, ci=None, palette='viridis')

# %%
sns.barplot(x='absences', y='Note_Final', data=df)
plt.xlabel('Absences')
plt.ylabel('Moyenne des notes')
plt.title('Impact de l\'absence sur les etudiants')
plt.show()

# %%
plt.figure(figsize=(7, 4))
sns.barplot(x='absences', y='Note_Final', data=df, ci=None, palette='viridis')

plt.xlabel('Absences')
plt.ylabel('Moyenne des notes')
plt.title('Impact de l\'absence sur les etudiants')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3320\1764171411.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='absences', y='Note_Final', data=df, ci=None, palette='viridis')

# %%
plt.figure(figsize=(7, 4))
sns.barplot(x='Dciga', y='Note_Final', data=df, ci=None, palette='viridis')

plt.xlabel('Cigarettes par jour')
plt.ylabel('Moyenne des notes')
plt.title('Impact des cigarettes sur les étudiants')

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(rotation=0)
plt.tight_layout()

plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3320\1830018992.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Dciga', y='Note_Final', data=df, ci=None, palette='viridis')

# %%
sns.barplot(x='Dciga', y='Note_Final', data=df)
plt.xlabel('Daily Cigarette')
plt.ylabel('Moyenne des notes')
plt.title('Impact des Cigarette sur les etudiants')
plt.show()

# %%
sns.barplot(x='romantic', y='Note_Final', data=df)
plt.xlabel('En Relation')
plt.ylabel('Moyenne des notes')
plt.title('Impact des Relation sur les etudiants')
plt.show()

# %%
df.head(5)
# Out:
#    Numero appoge     Last Name First Name sex  age        City  Annee Filier  \
# 0       20000773       ABETIOU    SOFIANE   M   20     Larache   2023   GINF
# 1       19001211      ACHERNAN    MOHAMED   M   20      Tanger   2023   GINF
# 2       19001137         AFOUD       HIND   F   20      Tanger   2023   GINF
# 3       20000734  AIT OUKHADOU      SELMA   F   20  Casablanca   2023   GINF
# 4       20000761       AKIIRNE       AMAL   F   20  Casablanca   2023   GINF
#
#   Matiere famsize  ... romantic  famrel  freetime Dciga Wciga health absences  \
# 0     C++     LE3  ...       no       5         4     1     2      5       10
# 1     C++     LE3  ...       no       4         3     1     2      5        2
# 2     C++     GT3  ...       no       5         4     1     2      3        2
# 3     C++     GT3  ...       no       4         4     1     1      1        0
# 4     C++     GT3  ...       no       4         3     1     1      5        2
#
#    CC1  CC2  Note_Final
# ...

# %%
df_resumer = df.loc[:,['Numero appoge', 'Last Name', 'First Name', 'Note_Final']]
df_resumer
# Out:
#     Numero appoge     Last Name         First Name  Note_Final
# 0        20000773       ABETIOU            SOFIANE        12.5
# 1        19001211      ACHERNAN            MOHAMED        15.5
# 2        19001137         AFOUD               HIND        15.0
# 3        20000734  AIT OUKHADOU              SELMA        16.5
# 4        20000761       AKIIRNE               AMAL        12.5
# 5        19001276     AMHAOUECH               WIAM         9.0
# 6        20001244         AMINE               TAHA         7.0
# 7        20000493         ARRAB              HAFSA        18.5
# 8        20006988         BAJJI              AMINE        17.0
# 9        20007078       BENAMRI             AYMANE        10.0
# 10       20000757      BENATTOU              IMANE        12.0
# 11       20000758      BENATTOU             IHSANE        11.5
# 12       19002165    BENTOUFILE            OUSSAMA        13.0
# 13       20002424      BOUKTAIB            SOUFIAN         9.5
# ...

# %%
df_resumer.to_csv('GINF_AFFICHAGE.csv', index=False)
